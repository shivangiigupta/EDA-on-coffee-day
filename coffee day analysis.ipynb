# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s= pd.read_csv("coffee_df.csv")

# %%
s
# Out:
#                        location  \
# 0            Madison, Wisconsin
# 1         San Diego, California
# 2          Glendale, California
# 3          Glendale, California
# 4           Redding, California
# ...                         ...
# 2277  Highland Park, New Jersey
# 2278             Taipei, Taiwan
# 2279      Branford, Connecticut
# 2280      San Diego, California
# 2281     San Rafael, California
#
#                                                  origin         roast  \
# 0                  Piendamó, Cauca Department, Colombia  Medium-Light
# 1        Trujillo, Valle del Cauca Department, Colombia         Light
# 2         Yirgacheffe growing region, southern Ethiopia  Medium-Light
# 3                                      Tolima, Colombia  Medium-Light
# 4                 Volcan growing region, western Panama         Light
# ...                                                 ...           ...
# 2277                       Biolley, southern Costa Rica  Medium-Light
# ...

# %%
s.head(50)
# Out:
#                   location                                             origin  \
# 0       Madison, Wisconsin               Piendamó, Cauca Department, Colombia
# 1    San Diego, California     Trujillo, Valle del Cauca Department, Colombia
# 2     Glendale, California      Yirgacheffe growing region, southern Ethiopia
# 3     Glendale, California                                   Tolima, Colombia
# 4      Redding, California              Volcan growing region, western Panama
# 5      Redding, California              Volcan growing region, western Panama
# 6      Redding, California              Volcan growing region, western Panama
# 7     Minnesota, Minnesota           Bombe Mountains, Sidama Region, Ethiopia
# 8   Minneapolis, Minnesota      Yirgacheffe growing region, southern Ethiopia
# 9        Manlius, New York                   Coatepec, Veracruz State, Mexico
# 10       Durango, Colorado  Sabanilla de Alajuela, Alajuela Province, Cost...
# ...

# %%
s.tail(20)
# Out:
#                        location  \
# 2262         Lee, Massachusetts
# 2263            Portland, Maine
# 2264            Chia-Yi, Taiwan
# 2265          Chino, California
# 2266            Chia-Yi, Taiwan
# 2267      San Diego, California
# 2268          Chino, California
# 2269         Montrose, Colorado
# 2270        Spokane, Washington
# 2271            Floyd, Virginia
# 2272            Portland, Maine
# 2273            Hsinchu, Taiwan
# 2274       Louisville, Kentucky
# 2275     Bedford, New Hampshire
# 2276          Boulder, Colorado
# 2277  Highland Park, New Jersey
# 2278             Taipei, Taiwan
# 2279      Branford, Connecticut
# 2280      San Diego, California
# 2281     San Rafael, California
#
#                                                  origin         roast  \
# 2262                                Jinotega, Nicaragua         Light
# 2263  Mukaro, Nyeri growing region, south-central Kenya  Medium-Light
# ...

# %%
s.shape   #matrix row and column
# Out:
# (2282, 15)

# %%
s.describe()
# Out:
#              aroma         acid         body       flavor   aftertaste  \
# count  2256.000000  1955.000000  2280.000000  2280.000000  2280.000000
# mean      8.819592     8.491049     8.595175     8.942105     8.091667
# std       0.487345     0.635279     0.529659     0.445522     0.553358
# min       2.000000     1.000000     5.000000     2.000000     2.000000
# 25%       9.000000     8.000000     8.000000     9.000000     8.000000
# 50%       9.000000     9.000000     9.000000     9.000000     8.000000
# 75%       9.000000     9.000000     9.000000     9.000000     8.000000
# max      10.000000    10.000000    10.000000    10.000000    10.000000
#
#         with_milk
# count  349.000000
# mean     8.842407
# std      0.509486
# min      5.000000
# 25%      9.000000
# 50%      9.000000
# 75%      9.000000
# max     10.000000

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2282 entries, 0 to 2281
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   location     2282 non-null   object
#  1   origin       2282 non-null   object
#  2   roast        2229 non-null   object
#  3   est_price    2277 non-null   object
#  4   review_date  2282 non-null   object
#  5   agtron       2282 non-null   object
#  6   aroma        2256 non-null   float64
#  7   acid         1955 non-null   float64
#  8   body         2280 non-null   float64
#  9   flavor       2280 non-null   float64
#  10  aftertaste   2280 non-null   float64
#  11  with_milk    349 non-null    float64
#  12  desc_1       2282 non-null   object
#  13  desc_2       2282 non-null   object
#  14  desc_3       2280 non-null   object
# dtypes: float64(6), object(9)
# memory usage: 267.5+ KB

# %%
s.isnull()
# Out:
#       location  origin  roast  est_price  review_date  agtron  aroma   acid  \
# 0        False   False  False      False        False   False  False  False
# 1        False   False  False      False        False   False  False  False
# 2        False   False  False      False        False   False  False  False
# 3        False   False  False      False        False   False  False  False
# 4        False   False  False      False        False   False  False  False
# ...        ...     ...    ...        ...          ...     ...    ...    ...
# 2277     False   False  False      False        False   False  False  False
# 2278     False   False  False      False        False   False  False  False
# 2279     False   False  False      False        False   False  False  False
# 2280     False   False  False      False        False   False  False  False
# 2281     False   False  False      False        False   False  False  False
#
# ...

# %%
s.isnull().sum()
# Out:
# location          0
# origin            0
# roast            53
# est_price         5
# review_date       0
# agtron            0
# aroma            26
# acid            327
# body              2
# flavor            2
# aftertaste        2
# with_milk      1933
# desc_1            0
# desc_2            0
# desc_3            2
# dtype: int64

# %%
import missingno

# %%
missingno.bar(s)
# Out:
# <AxesSubplot:>

# %%
missingno.matrix(s)
# Out:
# <AxesSubplot:>

# %%
missingno.heatmap(s)
# Out:
# <AxesSubplot:>

# %%
missingno.dendrogram(s)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.distplot(s["with_milk"])
# Out:
# C:\Users\shivangi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='with_milk', ylabel='Density'>

# %%
sns.distplot(s["body"])
# Out:
# C:\Users\shivangi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='body', ylabel='Density'>

# %%
sns.displot(s["with_milk"])

# %%
sns.displot(s["aroma"])

# %%
sns.distplot(s["flavor"],hist=False)
# Out:
# C:\Users\shivangi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='flavor', ylabel='Density'>

# %%
sns.distplot(s["with_milk"],hist_kws = dict(linewidth=2,edgecolor="r"))
# Out:
# C:\Users\shivangi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='with_milk', ylabel='Density'>

# %%
sns.set_style("whitegrid")

# %%
sns.displot(s["with_milk"])

# %%
sns.displot(s["with_milk"])

# %%
s.mean()
# Out:
# C:\Users\shivangi\AppData\Local\Temp\ipykernel_7036\842288822.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   s.mean()
# aroma         8.819592
# acid          8.491049
# body          8.595175
# flavor        8.942105
# aftertaste    8.091667
# with_milk     8.842407
# dtype: float64

# %%
x,y =plt.subplots(figsize=(8,8))
sns.distplot(s["flavor"],hist=False, ax=y)
y.axvline(s["flavor"].mean(),color="r",ls="--")
# Out:
# C:\Users\shivangi\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
uniquename=[]
for i in s.columns:
    x=s[i].value_counts().count()
    uniquename.append(x)
    

pd.DataFrame(uniquename,index=s.columns,columns=["total unique names"])
# Out:
#              total unique names
# location                    298
# origin                      988
# roast                         5
# est_price                   809
# review_date                  60
# agtron                      323
# aroma                         8
# acid                          8
# body                          6
# flavor                        7
# aftertaste                    9
# with_milk                     5
# desc_1                     2280
# desc_2                     2206
# desc_3                     2278
